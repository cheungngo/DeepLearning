# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Specify data URI
URI = './data/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URI)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %%
# visualizing the data

print(df.shape)
print("===")
print(df)
print("===")
print(df.pop("Y1"))
# Out:
# (768, 10)
# ===
#        X1     X2     X3     X4   X5  X6    X7  X8     Y1     Y2
# 0    0.82  612.5  318.5  147.0  7.0   4  0.25   4  25.43  28.76
# 1    0.66  759.5  318.5  220.5  3.5   2  0.25   3  12.97  15.53
# 2    0.62  808.5  367.5  220.5  3.5   2  0.40   4  16.44  17.10
# 3    0.74  686.0  245.0  220.5  3.5   2  0.10   4  10.08  13.20
# 4    0.76  661.5  416.5  122.5  7.0   3  0.40   5  39.72  39.80
# ..    ...    ...    ...    ...  ...  ..   ...  ..    ...    ...
# 763  0.74  686.0  245.0  220.5  3.5   5  0.25   5  12.02  14.03
# 764  0.79  637.0  343.0  147.0  7.0   4  0.40   5  41.09  47.01
# 765  0.86  588.0  294.0  147.0  7.0   4  0.25   4  29.08  33.93
# 766  0.90  563.5  318.5  122.5  7.0   4  0.10   3  29.62  30.08
# 767  0.74  686.0  245.0  220.5  3.5   4  0.25   5  11.64  14.81
#
# [768 rows x 10 columns]
# ===
# 0      25.43
# 1      12.97
# 2      16.44
# 3      10.08
# 4      39.72
#        ...
# 763    12.02
# 764    41.09
# 765    29.08
# 766    29.62
# 767    11.64
# Name: Y1, Length: 768, dtype: float64

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 128)          1152        input_2[0][0]
# __________________________________________________________________________________________________
# dense_4 (Dense)                 (None, 128)          16512       dense_3[0][0]
# __________________________________________________________________________________________________
# dense_5 (Dense)                 (None, 64)           8256        dense_4[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_4[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_5[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
from tensorflow.python.keras.utils.vis_utils import plot_model
plot_model(model, show_shapes=True, show_layer_names=True, to_file='model.png')

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 0s 804us/sample - loss: 269.5398 - y1_output_loss: 126.4239 - y2_output_loss: 140.5432 - y1_output_root_mean_squared_error: 11.2985 - y2_output_root_mean_squared_error: 11.9115 - val_loss: 33.2833 - val_y1_output_loss: 15.0367 - val_y2_output_loss: 17.1767 - val_y1_output_root_mean_squared_error: 3.9387 - val_y2_output_root_mean_squared_error: 4.2154
# Epoch 2/500
# 614/614 [==============================] - 0s 129us/sample - loss: 29.8102 - y1_output_loss: 11.9737 - y2_output_loss: 17.9167 - y1_output_root_mean_squared_error: 3.4642 - y2_output_root_mean_squared_error: 4.2201 - val_loss: 74.6814 - val_y1_output_loss: 17.8254 - val_y2_output_loss: 54.6602 - val_y1_output_root_mean_squared_error: 4.2999 - val_y2_output_root_mean_squared_error: 7.4962
# Epoch 3/500
# 614/614 [==============================] - 0s 139us/sample - loss: 24.7391 - y1_output_loss: 10.0525 - y2_output_loss: 14.6250 - y1_output_root_mean_squared_error: 3.1695 - y2_output_root_mean_squared_error: 3.8332 - val_loss: 22.6684 - val_y1_output_loss: 9.2706 - val_y2_output_loss: 12.7872 - val_y1_output_root_mean_squared_error: 3.0828 - val_y2_output_root_mean_squared_error: 3.6284
# Epoch 4/500
# 614/614 [==============================] - 0s 125us/sample - loss: 27.2414 - y1_output_loss: 10.0678 - y2_output_loss: 16.9717 - y1_output_root_mean_squared_error: 3.1824 - y2_output_root_mean_squared_error: 4.1369 - val_loss: 23.0540 - val_y1_output_loss: 9.3404 - val_y2_output_loss: 13.0050 - val_y1_output_root_mean_squared_error: 3.1055 - val_y2_output_root_mean_squared_error: 3.6619
# Epoch 5/500
# 614/614 [==============================] - 0s 127us/sample - loss: 20.2612 - y1_output_loss: 8.5364 - y2_output_loss: 11.6344 - y1_output_root_mean_squared_error: 2.9310 - y2_output_root_mean_squared_error: 3.4162 - val_loss: 23.6494 - val_y1_output_loss: 9.3432 - val_y2_output_loss: 13.6854 - val_y1_output_root_mean_squared_error: 3.0968 - val_y2_output_root_mean_squared_error: 3.7496
# Epoch 6/500
# 614/614 [==============================] - 0s 131us/sample - loss: 23.0439 - y1_output_loss: 8.9892 - y2_output_loss: 13.8830 - y1_output_root_mean_squared_error: 3.0047 - y2_output_root_mean_squared_error: 3.7437 - val_loss: 18.2826 - val_y1_output_loss: 7.6015 - val_y2_output_loss: 10.1565 - val_y1_output_root_mean_squared_error: 2.8050 - val_y2_output_root_mean_squared_error: 3.2272
# Epoch 7/500
# 614/614 [==============================] - 0s 126us/sample - loss: 24.9311 - y1_output_loss: 9.3300 - y2_output_loss: 16.0682 - y1_output_root_mean_squared_error: 3.0195 - y2_output_root_mean_squared_error: 3.9766 - val_loss: 40.8991 - val_y1_output_loss: 12.6080 - val_y2_output_loss: 27.4312 - val_y1_output_root_mean_squared_error: 3.6123 - val_y2_output_root_mean_squared_error: 5.2774
# Epoch 8/500
# 614/614 [==============================] - 0s 124us/sample - loss: 20.3768 - y1_output_loss: 7.9976 - y2_output_loss: 12.2392 - y1_output_root_mean_squared_error: 2.8370 - y2_output_root_mean_squared_error: 3.5111 - val_loss: 20.9104 - val_y1_output_loss: 8.1123 - val_y2_output_loss: 12.2996 - val_y1_output_root_mean_squared_error: 2.8959 - val_y2_output_root_mean_squared_error: 3.5389
# Epoch 9/500
# 614/614 [==============================] - 0s 124us/sample - loss: 22.1754 - y1_output_loss: 8.2949 - y2_output_loss: 13.8023 - y1_output_root_mean_squared_error: 2.8899 - y2_output_root_mean_squared_error: 3.7180 - val_loss: 44.5610 - val_y1_output_loss: 10.6708 - val_y2_output_loss: 32.7058 - val_y1_output_root_mean_squared_error: 3.3094 - val_y2_output_root_mean_squared_error: 5.7973
# Epoch 10/500
# 614/614 [==============================] - 0s 124us/sample - loss: 20.5341 - y1_output_loss: 7.6726 - y2_output_loss: 12.7505 - y1_output_root_mean_squared_error: 2.7778 - y2_output_root_mean_squared_error: 3.5802 - val_loss: 17.4998 - val_y1_output_loss: 6.9844 - val_y2_output_loss: 10.1491 - val_y1_output_root_mean_squared_error: 2.6816 - val_y2_output_root_mean_squared_error: 3.2108
# Epoch 11/500
# 614/614 [==============================] - 0s 124us/sample - loss: 20.2178 - y1_output_loss: 7.5382 - y2_output_loss: 12.7082 - y1_output_root_mean_squared_error: 2.7523 - y2_output_root_mean_squared_error: 3.5556 - val_loss: 57.7314 - val_y1_output_loss: 11.5537 - val_y2_output_loss: 44.9513 - val_y1_output_root_mean_squared_error: 3.4598 - val_y2_output_root_mean_squared_error: 6.7647
# Epoch 12/500
# 614/614 [==============================] - 0s 124us/sample - loss: 18.1000 - y1_output_loss: 7.2531 - y2_output_loss: 10.7237 - y1_output_root_mean_squared_error: 2.7037 - y2_output_root_mean_squared_error: 3.2848 - val_loss: 15.9547 - val_y1_output_loss: 6.6228 - val_y2_output_loss: 9.0186 - val_y1_output_root_mean_squared_error: 2.6133 - val_y2_output_root_mean_squared_error: 3.0208
# Epoch 13/500
# 614/614 [==============================] - 0s 123us/sample - loss: 22.3101 - y1_output_loss: 7.8230 - y2_output_loss: 14.3054 - y1_output_root_mean_squared_error: 2.8077 - y2_output_root_mean_squared_error: 3.7983 - val_loss: 19.0938 - val_y1_output_loss: 7.3552 - val_y2_output_loss: 11.3167 - val_y1_output_root_mean_squared_error: 2.7546 - val_y2_output_root_mean_squared_error: 3.3921
# Epoch 14/500
# 614/614 [==============================] - 0s 124us/sample - loss: 17.7381 - y1_output_loss: 6.6159 - y2_output_loss: 10.9714 - y1_output_root_mean_squared_error: 2.5834 - y2_output_root_mean_squared_error: 3.3263 - val_loss: 15.9230 - val_y1_output_loss: 6.0618 - val_y2_output_loss: 9.5403 - val_y1_output_root_mean_squared_error: 2.4926 - val_y2_output_root_mean_squared_error: 3.1160
# Epoch 15/500
# 614/614 [==============================] - 0s 124us/sample - loss: 15.4949 - y1_output_loss: 6.4565 - y2_output_loss: 9.1122 - y1_output_root_mean_squared_error: 2.5250 - y2_output_root_mean_squared_error: 3.0198 - val_loss: 14.6027 - val_y1_output_loss: 5.6357 - val_y2_output_loss: 8.5402 - val_y1_output_root_mean_squared_error: 2.4103 - val_y2_output_root_mean_squared_error: 2.9653
# Epoch 16/500
# 614/614 [==============================] - 0s 123us/sample - loss: 17.7132 - y1_output_loss: 6.6566 - y2_output_loss: 11.0828 - y1_output_root_mean_squared_error: 2.5672 - y2_output_root_mean_squared_error: 3.3351 - val_loss: 15.3274 - val_y1_output_loss: 6.2947 - val_y2_output_loss: 8.7062 - val_y1_output_root_mean_squared_error: 2.5255 - val_y2_output_root_mean_squared_error: 2.9915
# Epoch 17/500
# 614/614 [==============================] - 0s 123us/sample - loss: 15.9941 - y1_output_loss: 6.3278 - y2_output_loss: 9.7578 - y1_output_root_mean_squared_error: 2.5048 - y2_output_root_mean_squared_error: 3.1177 - val_loss: 23.1017 - val_y1_output_loss: 7.3474 - val_y2_output_loss: 15.1859 - val_y1_output_root_mean_squared_error: 2.7328 - val_y2_output_root_mean_squared_error: 3.9539
# Epoch 18/500
# 614/614 [==============================] - 0s 123us/sample - loss: 14.1382 - y1_output_loss: 5.3912 - y2_output_loss: 8.6737 - y1_output_root_mean_squared_error: 2.3290 - y2_output_root_mean_squared_error: 2.9520 - val_loss: 15.9119 - val_y1_output_loss: 5.2017 - val_y2_output_loss: 10.3693 - val_y1_output_root_mean_squared_error: 2.2989 - val_y2_output_root_mean_squared_error: 3.2599
# Epoch 19/500
# 614/614 [==============================] - 0s 123us/sample - loss: 16.1171 - y1_output_loss: 6.0361 - y2_output_loss: 10.1632 - y1_output_root_mean_squared_error: 2.4405 - y2_output_root_mean_squared_error: 3.1877 - val_loss: 14.5227 - val_y1_output_loss: 5.9125 - val_y2_output_loss: 8.5131 - val_y1_output_root_mean_squared_error: 2.4147 - val_y2_output_root_mean_squared_error: 2.9482
# Epoch 20/500
# 614/614 [==============================] - 0s 123us/sample - loss: 15.9136 - y1_output_loss: 5.5194 - y2_output_loss: 10.3594 - y1_output_root_mean_squared_error: 2.3465 - y2_output_root_mean_squared_error: 3.2260 - val_loss: 13.8508 - val_y1_output_loss: 5.6503 - val_y2_output_loss: 8.0276 - val_y1_output_root_mean_squared_error: 2.3759 - val_y2_output_root_mean_squared_error: 2.8646
# Epoch 21/500
# 614/614 [==============================] - 0s 128us/sample - loss: 12.8770 - y1_output_loss: 4.9598 - y2_output_loss: 7.9018 - y1_output_root_mean_squared_error: 2.2193 - y2_output_root_mean_squared_error: 2.8199 - val_loss: 10.5713 - val_y1_output_loss: 4.3813 - val_y2_output_loss: 5.9674 - val_y1_output_root_mean_squared_error: 2.1065 - val_y2_output_root_mean_squared_error: 2.4767
# Epoch 22/500
# 614/614 [==============================] - 0s 125us/sample - loss: 16.3239 - y1_output_loss: 5.4956 - y2_output_loss: 10.8010 - y1_output_root_mean_squared_error: 2.3531 - y2_output_root_mean_squared_error: 3.2843 - val_loss: 10.7962 - val_y1_output_loss: 4.0641 - val_y2_output_loss: 6.5720 - val_y1_output_root_mean_squared_error: 2.0318 - val_y2_output_root_mean_squared_error: 2.5822
# Epoch 23/500
# 614/614 [==============================] - 0s 127us/sample - loss: 14.1781 - y1_output_loss: 5.0204 - y2_output_loss: 9.4605 - y1_output_root_mean_squared_error: 2.2103 - y2_output_root_mean_squared_error: 3.0484 - val_loss: 48.2272 - val_y1_output_loss: 12.6917 - val_y2_output_loss: 34.4557 - val_y1_output_root_mean_squared_error: 3.5837 - val_y2_output_root_mean_squared_error: 5.9485
# Epoch 24/500
# 614/614 [==============================] - 0s 123us/sample - loss: 11.4570 - y1_output_loss: 4.2743 - y2_output_loss: 7.0822 - y1_output_root_mean_squared_error: 2.0771 - y2_output_root_mean_squared_error: 2.6726 - val_loss: 16.4018 - val_y1_output_loss: 5.1653 - val_y2_output_loss: 10.8260 - val_y1_output_root_mean_squared_error: 2.3054 - val_y2_output_root_mean_squared_error: 3.3297
# Epoch 25/500
# 614/614 [==============================] - 0s 124us/sample - loss: 12.9617 - y1_output_loss: 4.4444 - y2_output_loss: 8.4158 - y1_output_root_mean_squared_error: 2.1156 - y2_output_root_mean_squared_error: 2.9131 - val_loss: 9.5649 - val_y1_output_loss: 3.6953 - val_y2_output_loss: 5.5882 - val_y1_output_root_mean_squared_error: 1.9434 - val_y2_output_root_mean_squared_error: 2.4058
# Epoch 26/500
# 614/614 [==============================] - 0s 124us/sample - loss: 12.5615 - y1_output_loss: 4.3281 - y2_output_loss: 8.2295 - y1_output_root_mean_squared_error: 2.0867 - y2_output_root_mean_squared_error: 2.8648 - val_loss: 18.3818 - val_y1_output_loss: 4.7247 - val_y2_output_loss: 13.2719 - val_y1_output_root_mean_squared_error: 2.1997 - val_y2_output_root_mean_squared_error: 3.6801
# Epoch 27/500
# 614/614 [==============================] - 0s 124us/sample - loss: 15.0310 - y1_output_loss: 4.7338 - y2_output_loss: 10.3109 - y1_output_root_mean_squared_error: 2.1688 - y2_output_root_mean_squared_error: 3.2136 - val_loss: 23.8001 - val_y1_output_loss: 5.7937 - val_y2_output_loss: 17.5486 - val_y1_output_root_mean_squared_error: 2.4018 - val_y2_output_root_mean_squared_error: 4.2463
# Epoch 28/500
# 614/614 [==============================] - 0s 124us/sample - loss: 10.2826 - y1_output_loss: 3.3949 - y2_output_loss: 6.7970 - y1_output_root_mean_squared_error: 1.8506 - y2_output_root_mean_squared_error: 2.6188 - val_loss: 8.1243 - val_y1_output_loss: 3.3267 - val_y2_output_loss: 4.6872 - val_y1_output_root_mean_squared_error: 1.8118 - val_y2_output_root_mean_squared_error: 2.2004
# Epoch 29/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.6445 - y1_output_loss: 3.1162 - y2_output_loss: 5.5469 - y1_output_root_mean_squared_error: 1.7629 - y2_output_root_mean_squared_error: 2.3530 - val_loss: 13.6850 - val_y1_output_loss: 5.6004 - val_y2_output_loss: 7.7506 - val_y1_output_root_mean_squared_error: 2.4054 - val_y2_output_root_mean_squared_error: 2.8105
# Epoch 30/500
# 614/614 [==============================] - 0s 124us/sample - loss: 10.1038 - y1_output_loss: 3.2667 - y2_output_loss: 6.7796 - y1_output_root_mean_squared_error: 1.8105 - y2_output_root_mean_squared_error: 2.6126 - val_loss: 8.8245 - val_y1_output_loss: 3.0567 - val_y2_output_loss: 5.6558 - val_y1_output_root_mean_squared_error: 1.7453 - val_y2_output_root_mean_squared_error: 2.4039
# Epoch 31/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.4018 - y1_output_loss: 2.8736 - y2_output_loss: 5.4684 - y1_output_root_mean_squared_error: 1.7017 - y2_output_root_mean_squared_error: 2.3465 - val_loss: 8.3379 - val_y1_output_loss: 3.3012 - val_y2_output_loss: 4.8596 - val_y1_output_root_mean_squared_error: 1.8222 - val_y2_output_root_mean_squared_error: 2.2400
# Epoch 32/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.9810 - y1_output_loss: 3.1424 - y2_output_loss: 5.7878 - y1_output_root_mean_squared_error: 1.7739 - y2_output_root_mean_squared_error: 2.4154 - val_loss: 6.3238 - val_y1_output_loss: 2.3257 - val_y2_output_loss: 3.9047 - val_y1_output_root_mean_squared_error: 1.5218 - val_y2_output_root_mean_squared_error: 2.0020
# Epoch 33/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.9248 - y1_output_loss: 2.5232 - y2_output_loss: 5.3712 - y1_output_root_mean_squared_error: 1.5882 - y2_output_root_mean_squared_error: 2.3243 - val_loss: 10.4693 - val_y1_output_loss: 3.4510 - val_y2_output_loss: 6.7977 - val_y1_output_root_mean_squared_error: 1.8784 - val_y2_output_root_mean_squared_error: 2.6345
# Epoch 34/500
# 614/614 [==============================] - 0s 124us/sample - loss: 10.2093 - y1_output_loss: 3.2209 - y2_output_loss: 6.8929 - y1_output_root_mean_squared_error: 1.8029 - y2_output_root_mean_squared_error: 2.6379 - val_loss: 8.1271 - val_y1_output_loss: 2.8668 - val_y2_output_loss: 5.1125 - val_y1_output_root_mean_squared_error: 1.6915 - val_y2_output_root_mean_squared_error: 2.2948
# Epoch 35/500
# 614/614 [==============================] - 0s 123us/sample - loss: 11.9633 - y1_output_loss: 3.8929 - y2_output_loss: 8.0616 - y1_output_root_mean_squared_error: 1.9733 - y2_output_root_mean_squared_error: 2.8407 - val_loss: 22.7889 - val_y1_output_loss: 5.5187 - val_y2_output_loss: 16.8693 - val_y1_output_root_mean_squared_error: 2.3920 - val_y2_output_root_mean_squared_error: 4.1313
# Epoch 36/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.3936 - y1_output_loss: 2.6774 - y2_output_loss: 5.6746 - y1_output_root_mean_squared_error: 1.6377 - y2_output_root_mean_squared_error: 2.3899 - val_loss: 7.1139 - val_y1_output_loss: 2.4969 - val_y2_output_loss: 4.4713 - val_y1_output_root_mean_squared_error: 1.5801 - val_y2_output_root_mean_squared_error: 2.1488
# Epoch 37/500
# 614/614 [==============================] - 0s 124us/sample - loss: 8.3844 - y1_output_loss: 2.5557 - y2_output_loss: 5.8060 - y1_output_root_mean_squared_error: 1.6057 - y2_output_root_mean_squared_error: 2.4096 - val_loss: 8.3432 - val_y1_output_loss: 2.1055 - val_y2_output_loss: 6.0221 - val_y1_output_root_mean_squared_error: 1.4538 - val_y2_output_root_mean_squared_error: 2.4959
# Epoch 38/500
# 614/614 [==============================] - 0s 129us/sample - loss: 8.4226 - y1_output_loss: 2.8330 - y2_output_loss: 5.5300 - y1_output_root_mean_squared_error: 1.6871 - y2_output_root_mean_squared_error: 2.3614 - val_loss: 6.4061 - val_y1_output_loss: 2.1488 - val_y2_output_loss: 4.2164 - val_y1_output_root_mean_squared_error: 1.4577 - val_y2_output_root_mean_squared_error: 2.0691
# Epoch 39/500
# 614/614 [==============================] - 0s 131us/sample - loss: 6.5337 - y1_output_loss: 2.1061 - y2_output_loss: 4.3702 - y1_output_root_mean_squared_error: 1.4572 - y2_output_root_mean_squared_error: 2.1001 - val_loss: 5.6669 - val_y1_output_loss: 2.0510 - val_y2_output_loss: 3.5103 - val_y1_output_root_mean_squared_error: 1.4420 - val_y2_output_root_mean_squared_error: 1.8941
# Epoch 40/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.4980 - y1_output_loss: 2.0854 - y2_output_loss: 4.4316 - y1_output_root_mean_squared_error: 1.4423 - y2_output_root_mean_squared_error: 2.1018 - val_loss: 9.3280 - val_y1_output_loss: 2.7329 - val_y2_output_loss: 6.4826 - val_y1_output_root_mean_squared_error: 1.6399 - val_y2_output_root_mean_squared_error: 2.5766
# Epoch 41/500
# 614/614 [==============================] - 0s 129us/sample - loss: 9.6616 - y1_output_loss: 2.8485 - y2_output_loss: 6.7489 - y1_output_root_mean_squared_error: 1.6935 - y2_output_root_mean_squared_error: 2.6064 - val_loss: 6.3881 - val_y1_output_loss: 2.2380 - val_y2_output_loss: 4.0448 - val_y1_output_root_mean_squared_error: 1.5069 - val_y2_output_root_mean_squared_error: 2.0291
# Epoch 42/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.8106 - y1_output_loss: 2.4187 - y2_output_loss: 5.3546 - y1_output_root_mean_squared_error: 1.5542 - y2_output_root_mean_squared_error: 2.3227 - val_loss: 5.8076 - val_y1_output_loss: 1.9667 - val_y2_output_loss: 3.7460 - val_y1_output_root_mean_squared_error: 1.4139 - val_y2_output_root_mean_squared_error: 1.9515
# Epoch 43/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.3128 - y1_output_loss: 2.0067 - y2_output_loss: 4.2518 - y1_output_root_mean_squared_error: 1.4233 - y2_output_root_mean_squared_error: 2.0705 - val_loss: 5.1871 - val_y1_output_loss: 1.6175 - val_y2_output_loss: 3.5339 - val_y1_output_root_mean_squared_error: 1.2810 - val_y2_output_root_mean_squared_error: 1.8831
# Epoch 44/500
# 614/614 [==============================] - 0s 131us/sample - loss: 7.7944 - y1_output_loss: 2.5298 - y2_output_loss: 5.2863 - y1_output_root_mean_squared_error: 1.5942 - y2_output_root_mean_squared_error: 2.2919 - val_loss: 16.2367 - val_y1_output_loss: 4.0520 - val_y2_output_loss: 11.8930 - val_y1_output_root_mean_squared_error: 2.0481 - val_y2_output_root_mean_squared_error: 3.4702
# Epoch 45/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.4599 - y1_output_loss: 2.2823 - y2_output_loss: 5.1986 - y1_output_root_mean_squared_error: 1.4997 - y2_output_root_mean_squared_error: 2.2827 - val_loss: 6.3535 - val_y1_output_loss: 2.1823 - val_y2_output_loss: 4.1164 - val_y1_output_root_mean_squared_error: 1.4686 - val_y2_output_root_mean_squared_error: 2.0486
# Epoch 46/500
# 614/614 [==============================] - 0s 130us/sample - loss: 6.2650 - y1_output_loss: 2.0822 - y2_output_loss: 4.3821 - y1_output_root_mean_squared_error: 1.3978 - y2_output_root_mean_squared_error: 2.0763 - val_loss: 45.0071 - val_y1_output_loss: 17.7973 - val_y2_output_loss: 25.7764 - val_y1_output_root_mean_squared_error: 4.2749 - val_y2_output_root_mean_squared_error: 5.1703
# Epoch 47/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.6803 - y1_output_loss: 2.4395 - y2_output_loss: 5.1691 - y1_output_root_mean_squared_error: 1.5693 - y2_output_root_mean_squared_error: 2.2842 - val_loss: 5.0375 - val_y1_output_loss: 1.6352 - val_y2_output_loss: 3.3300 - val_y1_output_root_mean_squared_error: 1.2814 - val_y2_output_root_mean_squared_error: 1.8427
# Epoch 48/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.0332 - y1_output_loss: 2.2865 - y2_output_loss: 5.7427 - y1_output_root_mean_squared_error: 1.5118 - y2_output_root_mean_squared_error: 2.3974 - val_loss: 5.0767 - val_y1_output_loss: 1.5925 - val_y2_output_loss: 3.4024 - val_y1_output_root_mean_squared_error: 1.2799 - val_y2_output_root_mean_squared_error: 1.8543
# Epoch 49/500
# 614/614 [==============================] - 0s 126us/sample - loss: 6.6659 - y1_output_loss: 1.9390 - y2_output_loss: 4.7037 - y1_output_root_mean_squared_error: 1.3881 - y2_output_root_mean_squared_error: 2.1769 - val_loss: 5.9152 - val_y1_output_loss: 1.8213 - val_y2_output_loss: 3.9693 - val_y1_output_root_mean_squared_error: 1.3629 - val_y2_output_root_mean_squared_error: 2.0144
# Epoch 50/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.6960 - y1_output_loss: 2.0660 - y2_output_loss: 4.7010 - y1_output_root_mean_squared_error: 1.4245 - y2_output_root_mean_squared_error: 2.1602 - val_loss: 14.1284 - val_y1_output_loss: 5.5440 - val_y2_output_loss: 8.2114 - val_y1_output_root_mean_squared_error: 2.3948 - val_y2_output_root_mean_squared_error: 2.8971
# Epoch 51/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.9437 - y1_output_loss: 2.0368 - y2_output_loss: 4.8649 - y1_output_root_mean_squared_error: 1.4278 - y2_output_root_mean_squared_error: 2.2148 - val_loss: 6.4890 - val_y1_output_loss: 2.0078 - val_y2_output_loss: 4.3320 - val_y1_output_root_mean_squared_error: 1.4313 - val_y2_output_root_mean_squared_error: 2.1072
# Epoch 52/500
# 614/614 [==============================] - 0s 127us/sample - loss: 5.3532 - y1_output_loss: 1.6907 - y2_output_loss: 3.6805 - y1_output_root_mean_squared_error: 1.2926 - y2_output_root_mean_squared_error: 1.9189 - val_loss: 4.8941 - val_y1_output_loss: 1.6296 - val_y2_output_loss: 3.1900 - val_y1_output_root_mean_squared_error: 1.2933 - val_y2_output_root_mean_squared_error: 1.7948
# Epoch 53/500
# 614/614 [==============================] - 0s 125us/sample - loss: 6.5021 - y1_output_loss: 1.8979 - y2_output_loss: 4.5456 - y1_output_root_mean_squared_error: 1.3842 - y2_output_root_mean_squared_error: 2.1415 - val_loss: 5.3955 - val_y1_output_loss: 1.7126 - val_y2_output_loss: 3.5959 - val_y1_output_root_mean_squared_error: 1.3250 - val_y2_output_root_mean_squared_error: 1.9079
# Epoch 54/500
# 614/614 [==============================] - 0s 123us/sample - loss: 9.7474 - y1_output_loss: 2.9352 - y2_output_loss: 6.7333 - y1_output_root_mean_squared_error: 1.7186 - y2_output_root_mean_squared_error: 2.6065 - val_loss: 5.4643 - val_y1_output_loss: 1.6118 - val_y2_output_loss: 3.7553 - val_y1_output_root_mean_squared_error: 1.2734 - val_y2_output_root_mean_squared_error: 1.9603
# Epoch 55/500
# 614/614 [==============================] - 0s 123us/sample - loss: 5.9349 - y1_output_loss: 1.7019 - y2_output_loss: 4.2092 - y1_output_root_mean_squared_error: 1.3046 - y2_output_root_mean_squared_error: 2.0574 - val_loss: 7.2899 - val_y1_output_loss: 2.7939 - val_y2_output_loss: 4.3438 - val_y1_output_root_mean_squared_error: 1.6798 - val_y2_output_root_mean_squared_error: 2.1138
# Epoch 56/500
# 614/614 [==============================] - 0s 124us/sample - loss: 6.0064 - y1_output_loss: 1.6416 - y2_output_loss: 4.4008 - y1_output_root_mean_squared_error: 1.2711 - y2_output_root_mean_squared_error: 2.0954 - val_loss: 9.6792 - val_y1_output_loss: 3.3358 - val_y2_output_loss: 6.0932 - val_y1_output_root_mean_squared_error: 1.8347 - val_y2_output_root_mean_squared_error: 2.5126
# Epoch 57/500
# 614/614 [==============================] - 0s 124us/sample - loss: 5.4776 - y1_output_loss: 1.5968 - y2_output_loss: 3.8371 - y1_output_root_mean_squared_error: 1.2681 - y2_output_root_mean_squared_error: 1.9671 - val_loss: 5.4804 - val_y1_output_loss: 1.5517 - val_y2_output_loss: 3.9609 - val_y1_output_root_mean_squared_error: 1.2653 - val_y2_output_root_mean_squared_error: 1.9696
# Epoch 58/500
# 614/614 [==============================] - 0s 125us/sample - loss: 5.7157 - y1_output_loss: 1.5734 - y2_output_loss: 4.1735 - y1_output_root_mean_squared_error: 1.2518 - y2_output_root_mean_squared_error: 2.0368 - val_loss: 14.4383 - val_y1_output_loss: 3.0614 - val_y2_output_loss: 10.9855 - val_y1_output_root_mean_squared_error: 1.7461 - val_y2_output_root_mean_squared_error: 3.3748
# Epoch 59/500
# 614/614 [==============================] - 0s 123us/sample - loss: 5.5463 - y1_output_loss: 1.4827 - y2_output_loss: 4.0792 - y1_output_root_mean_squared_error: 1.2171 - y2_output_root_mean_squared_error: 2.0162 - val_loss: 8.7248 - val_y1_output_loss: 1.9214 - val_y2_output_loss: 6.5536 - val_y1_output_root_mean_squared_error: 1.3978 - val_y2_output_root_mean_squared_error: 2.6021
# Epoch 60/500
# 614/614 [==============================] - 0s 123us/sample - loss: 5.8024 - y1_output_loss: 1.8499 - y2_output_loss: 3.9156 - y1_output_root_mean_squared_error: 1.3659 - y2_output_root_mean_squared_error: 1.9841 - val_loss: 4.3973 - val_y1_output_loss: 1.2551 - val_y2_output_loss: 3.1633 - val_y1_output_root_mean_squared_error: 1.1361 - val_y2_output_root_mean_squared_error: 1.7625
# Epoch 61/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.4178 - y1_output_loss: 1.1815 - y2_output_loss: 3.2154 - y1_output_root_mean_squared_error: 1.0882 - y2_output_root_mean_squared_error: 1.7982 - val_loss: 5.2247 - val_y1_output_loss: 1.1857 - val_y2_output_loss: 3.9317 - val_y1_output_root_mean_squared_error: 1.0905 - val_y2_output_root_mean_squared_error: 2.0089
# Epoch 62/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.3350 - y1_output_loss: 1.1158 - y2_output_loss: 3.2051 - y1_output_root_mean_squared_error: 1.0509 - y2_output_root_mean_squared_error: 1.7974 - val_loss: 6.3994 - val_y1_output_loss: 2.1406 - val_y2_output_loss: 4.2532 - val_y1_output_root_mean_squared_error: 1.4888 - val_y2_output_root_mean_squared_error: 2.0452
# Epoch 63/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.6452 - y1_output_loss: 1.2394 - y2_output_loss: 3.4366 - y1_output_root_mean_squared_error: 1.1067 - y2_output_root_mean_squared_error: 1.8495 - val_loss: 6.6242 - val_y1_output_loss: 2.9295 - val_y2_output_loss: 3.5997 - val_y1_output_root_mean_squared_error: 1.7400 - val_y2_output_root_mean_squared_error: 1.8965
# Epoch 64/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.2293 - y1_output_loss: 1.1363 - y2_output_loss: 3.0749 - y1_output_root_mean_squared_error: 1.0682 - y2_output_root_mean_squared_error: 1.7573 - val_loss: 3.9785 - val_y1_output_loss: 1.1058 - val_y2_output_loss: 2.8986 - val_y1_output_root_mean_squared_error: 1.0660 - val_y2_output_root_mean_squared_error: 1.6859
# Epoch 65/500
# 614/614 [==============================] - 0s 123us/sample - loss: 5.0520 - y1_output_loss: 1.2500 - y2_output_loss: 3.7600 - y1_output_root_mean_squared_error: 1.1216 - y2_output_root_mean_squared_error: 1.9478 - val_loss: 3.5269 - val_y1_output_loss: 0.9097 - val_y2_output_loss: 2.6365 - val_y1_output_root_mean_squared_error: 0.9617 - val_y2_output_root_mean_squared_error: 1.6131
# Epoch 66/500
# 614/614 [==============================] - 0s 123us/sample - loss: 5.1901 - y1_output_loss: 1.4243 - y2_output_loss: 3.7309 - y1_output_root_mean_squared_error: 1.1957 - y2_output_root_mean_squared_error: 1.9392 - val_loss: 3.7313 - val_y1_output_loss: 1.1796 - val_y2_output_loss: 2.5614 - val_y1_output_root_mean_squared_error: 1.1041 - val_y2_output_root_mean_squared_error: 1.5850
# Epoch 67/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.4378 - y1_output_loss: 0.8913 - y2_output_loss: 2.5191 - y1_output_root_mean_squared_error: 0.9473 - y2_output_root_mean_squared_error: 1.5939 - val_loss: 5.1714 - val_y1_output_loss: 1.3379 - val_y2_output_loss: 3.8751 - val_y1_output_root_mean_squared_error: 1.1762 - val_y2_output_root_mean_squared_error: 1.9463
# Epoch 68/500
# 614/614 [==============================] - 0s 124us/sample - loss: 7.0707 - y1_output_loss: 2.0067 - y2_output_loss: 5.0287 - y1_output_root_mean_squared_error: 1.4192 - y2_output_root_mean_squared_error: 2.2486 - val_loss: 8.0068 - val_y1_output_loss: 1.8009 - val_y2_output_loss: 6.2743 - val_y1_output_root_mean_squared_error: 1.3660 - val_y2_output_root_mean_squared_error: 2.4781
# Epoch 69/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.8881 - y1_output_loss: 1.1176 - y2_output_loss: 3.7738 - y1_output_root_mean_squared_error: 1.0582 - y2_output_root_mean_squared_error: 1.9412 - val_loss: 3.7062 - val_y1_output_loss: 0.8622 - val_y2_output_loss: 2.8020 - val_y1_output_root_mean_squared_error: 0.9306 - val_y2_output_root_mean_squared_error: 1.6853
# Epoch 70/500
# 614/614 [==============================] - 0s 122us/sample - loss: 4.3176 - y1_output_loss: 1.0842 - y2_output_loss: 3.2432 - y1_output_root_mean_squared_error: 1.0381 - y2_output_root_mean_squared_error: 1.8000 - val_loss: 3.9032 - val_y1_output_loss: 0.9924 - val_y2_output_loss: 2.8744 - val_y1_output_root_mean_squared_error: 0.9898 - val_y2_output_root_mean_squared_error: 1.7098
# Epoch 71/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.2476 - y1_output_loss: 1.0596 - y2_output_loss: 3.1827 - y1_output_root_mean_squared_error: 1.0305 - y2_output_root_mean_squared_error: 1.7848 - val_loss: 3.3564 - val_y1_output_loss: 1.0078 - val_y2_output_loss: 2.3634 - val_y1_output_root_mean_squared_error: 1.0033 - val_y2_output_root_mean_squared_error: 1.5329
# Epoch 72/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.4024 - y1_output_loss: 0.7837 - y2_output_loss: 2.6417 - y1_output_root_mean_squared_error: 0.8882 - y2_output_root_mean_squared_error: 1.6167 - val_loss: 15.1099 - val_y1_output_loss: 2.0432 - val_y2_output_loss: 12.8958 - val_y1_output_root_mean_squared_error: 1.4485 - val_y2_output_root_mean_squared_error: 3.6072
# Epoch 73/500
# 614/614 [==============================] - 0s 123us/sample - loss: 4.5260 - y1_output_loss: 1.1192 - y2_output_loss: 3.3776 - y1_output_root_mean_squared_error: 1.0621 - y2_output_root_mean_squared_error: 1.8434 - val_loss: 4.6066 - val_y1_output_loss: 0.8112 - val_y2_output_loss: 3.6954 - val_y1_output_root_mean_squared_error: 0.8979 - val_y2_output_root_mean_squared_error: 1.9494
# Epoch 74/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.8275 - y1_output_loss: 0.9513 - y2_output_loss: 2.8493 - y1_output_root_mean_squared_error: 0.9791 - y2_output_root_mean_squared_error: 1.6937 - val_loss: 3.3167 - val_y1_output_loss: 0.7609 - val_y2_output_loss: 2.6235 - val_y1_output_root_mean_squared_error: 0.8842 - val_y2_output_root_mean_squared_error: 1.5921
# Epoch 75/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.4213 - y1_output_loss: 0.8190 - y2_output_loss: 2.5875 - y1_output_root_mean_squared_error: 0.9069 - y2_output_root_mean_squared_error: 1.6121 - val_loss: 3.6911 - val_y1_output_loss: 0.7441 - val_y2_output_loss: 3.0280 - val_y1_output_root_mean_squared_error: 0.8687 - val_y2_output_root_mean_squared_error: 1.7136
# Epoch 76/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.2106 - y1_output_loss: 0.7196 - y2_output_loss: 2.4748 - y1_output_root_mean_squared_error: 0.8511 - y2_output_root_mean_squared_error: 1.5768 - val_loss: 3.4919 - val_y1_output_loss: 1.1010 - val_y2_output_loss: 2.4028 - val_y1_output_root_mean_squared_error: 1.0496 - val_y2_output_root_mean_squared_error: 1.5461
# Epoch 77/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.8305 - y1_output_loss: 0.6849 - y2_output_loss: 2.1614 - y1_output_root_mean_squared_error: 0.8245 - y2_output_root_mean_squared_error: 1.4665 - val_loss: 3.0194 - val_y1_output_loss: 0.6309 - val_y2_output_loss: 2.3916 - val_y1_output_root_mean_squared_error: 0.7960 - val_y2_output_root_mean_squared_error: 1.5446
# Epoch 78/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.5595 - y1_output_loss: 0.9577 - y2_output_loss: 2.6051 - y1_output_root_mean_squared_error: 0.9782 - y2_output_root_mean_squared_error: 1.6132 - val_loss: 3.7674 - val_y1_output_loss: 1.1900 - val_y2_output_loss: 2.5527 - val_y1_output_root_mean_squared_error: 1.0843 - val_y2_output_root_mean_squared_error: 1.6099
# Epoch 79/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.8690 - y1_output_loss: 0.9879 - y2_output_loss: 2.9151 - y1_output_root_mean_squared_error: 0.9930 - y2_output_root_mean_squared_error: 1.6979 - val_loss: 7.2742 - val_y1_output_loss: 1.9595 - val_y2_output_loss: 5.3665 - val_y1_output_root_mean_squared_error: 1.4223 - val_y2_output_root_mean_squared_error: 2.2916
# Epoch 80/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.9083 - y1_output_loss: 0.7345 - y2_output_loss: 2.1495 - y1_output_root_mean_squared_error: 0.8599 - y2_output_root_mean_squared_error: 1.4727 - val_loss: 2.5415 - val_y1_output_loss: 0.5686 - val_y2_output_loss: 2.0281 - val_y1_output_root_mean_squared_error: 0.7538 - val_y2_output_root_mean_squared_error: 1.4047
# Epoch 81/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.9754 - y1_output_loss: 0.8664 - y2_output_loss: 3.1713 - y1_output_root_mean_squared_error: 0.9336 - y2_output_root_mean_squared_error: 1.7618 - val_loss: 12.8692 - val_y1_output_loss: 1.7778 - val_y2_output_loss: 10.7070 - val_y1_output_root_mean_squared_error: 1.3443 - val_y2_output_root_mean_squared_error: 3.3260
# Epoch 82/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.3846 - y1_output_loss: 1.1590 - y2_output_loss: 3.2123 - y1_output_root_mean_squared_error: 1.0785 - y2_output_root_mean_squared_error: 1.7948 - val_loss: 3.4770 - val_y1_output_loss: 0.6496 - val_y2_output_loss: 2.8013 - val_y1_output_root_mean_squared_error: 0.8054 - val_y2_output_root_mean_squared_error: 1.6818
# Epoch 83/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.1771 - y1_output_loss: 1.0311 - y2_output_loss: 3.1640 - y1_output_root_mean_squared_error: 1.0149 - y2_output_root_mean_squared_error: 1.7740 - val_loss: 5.0062 - val_y1_output_loss: 1.6067 - val_y2_output_loss: 3.4650 - val_y1_output_root_mean_squared_error: 1.2697 - val_y2_output_root_mean_squared_error: 1.8423
# Epoch 84/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.5132 - y1_output_loss: 0.8774 - y2_output_loss: 2.8224 - y1_output_root_mean_squared_error: 0.9029 - y2_output_root_mean_squared_error: 1.6425 - val_loss: 33.9226 - val_y1_output_loss: 13.3378 - val_y2_output_loss: 19.5780 - val_y1_output_root_mean_squared_error: 3.7219 - val_y2_output_root_mean_squared_error: 4.4800
# Epoch 85/500
# 614/614 [==============================] - 0s 131us/sample - loss: 4.5360 - y1_output_loss: 1.3997 - y2_output_loss: 3.1858 - y1_output_root_mean_squared_error: 1.1734 - y2_output_root_mean_squared_error: 1.7774 - val_loss: 10.0052 - val_y1_output_loss: 3.4828 - val_y2_output_loss: 6.3903 - val_y1_output_root_mean_squared_error: 1.9005 - val_y2_output_root_mean_squared_error: 2.5285
# Epoch 86/500
# 614/614 [==============================] - 0s 127us/sample - loss: 4.0741 - y1_output_loss: 1.1648 - y2_output_loss: 2.8795 - y1_output_root_mean_squared_error: 1.0821 - y2_output_root_mean_squared_error: 1.7039 - val_loss: 2.6909 - val_y1_output_loss: 0.7358 - val_y2_output_loss: 2.0290 - val_y1_output_root_mean_squared_error: 0.8562 - val_y2_output_root_mean_squared_error: 1.3992
# Epoch 87/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.5299 - y1_output_loss: 1.2577 - y2_output_loss: 3.2579 - y1_output_root_mean_squared_error: 1.1194 - y2_output_root_mean_squared_error: 1.8102 - val_loss: 7.3612 - val_y1_output_loss: 2.1896 - val_y2_output_loss: 5.1212 - val_y1_output_root_mean_squared_error: 1.4711 - val_y2_output_root_mean_squared_error: 2.2797
# Epoch 88/500
# 614/614 [==============================] - 0s 131us/sample - loss: 2.5200 - y1_output_loss: 0.6170 - y2_output_loss: 1.8907 - y1_output_root_mean_squared_error: 0.7884 - y2_output_root_mean_squared_error: 1.3779 - val_loss: 3.3984 - val_y1_output_loss: 0.9783 - val_y2_output_loss: 2.4306 - val_y1_output_root_mean_squared_error: 0.9892 - val_y2_output_root_mean_squared_error: 1.5556
# Epoch 89/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.9718 - y1_output_loss: 0.6733 - y2_output_loss: 2.2814 - y1_output_root_mean_squared_error: 0.8193 - y2_output_root_mean_squared_error: 1.5167 - val_loss: 2.6755 - val_y1_output_loss: 0.7019 - val_y2_output_loss: 1.9835 - val_y1_output_root_mean_squared_error: 0.8373 - val_y2_output_root_mean_squared_error: 1.4051
# Epoch 90/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.4445 - y1_output_loss: 0.5104 - y2_output_loss: 2.0010 - y1_output_root_mean_squared_error: 0.7111 - y2_output_root_mean_squared_error: 1.3924 - val_loss: 7.8378 - val_y1_output_loss: 1.8747 - val_y2_output_loss: 6.0559 - val_y1_output_root_mean_squared_error: 1.3930 - val_y2_output_root_mean_squared_error: 2.4285
# Epoch 91/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.7161 - y1_output_loss: 0.6296 - y2_output_loss: 2.1073 - y1_output_root_mean_squared_error: 0.7823 - y2_output_root_mean_squared_error: 1.4505 - val_loss: 4.8056 - val_y1_output_loss: 1.5334 - val_y2_output_loss: 3.3992 - val_y1_output_root_mean_squared_error: 1.2348 - val_y2_output_root_mean_squared_error: 1.8113
# Epoch 92/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.0988 - y1_output_loss: 0.6842 - y2_output_loss: 2.3937 - y1_output_root_mean_squared_error: 0.8280 - y2_output_root_mean_squared_error: 1.5534 - val_loss: 2.7164 - val_y1_output_loss: 0.6230 - val_y2_output_loss: 2.1474 - val_y1_output_root_mean_squared_error: 0.7979 - val_y2_output_root_mean_squared_error: 1.4421
# Epoch 93/500
# 614/614 [==============================] - 0s 153us/sample - loss: 4.5730 - y1_output_loss: 1.1289 - y2_output_loss: 3.4115 - y1_output_root_mean_squared_error: 1.0665 - y2_output_root_mean_squared_error: 1.8535 - val_loss: 2.4393 - val_y1_output_loss: 0.5002 - val_y2_output_loss: 1.9605 - val_y1_output_root_mean_squared_error: 0.7014 - val_y2_output_root_mean_squared_error: 1.3955
# Epoch 94/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.7410 - y1_output_loss: 0.6373 - y2_output_loss: 2.0865 - y1_output_root_mean_squared_error: 0.7983 - y2_output_root_mean_squared_error: 1.4504 - val_loss: 2.8985 - val_y1_output_loss: 0.7087 - val_y2_output_loss: 2.2026 - val_y1_output_root_mean_squared_error: 0.8487 - val_y2_output_root_mean_squared_error: 1.4759
# Epoch 95/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.0936 - y1_output_loss: 0.6163 - y2_output_loss: 2.4755 - y1_output_root_mean_squared_error: 0.7881 - y2_output_root_mean_squared_error: 1.5724 - val_loss: 6.6910 - val_y1_output_loss: 1.1023 - val_y2_output_loss: 5.4035 - val_y1_output_root_mean_squared_error: 1.0502 - val_y2_output_root_mean_squared_error: 2.3639
# Epoch 96/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.4463 - y1_output_loss: 0.5988 - y2_output_loss: 1.8292 - y1_output_root_mean_squared_error: 0.7750 - y2_output_root_mean_squared_error: 1.3586 - val_loss: 3.0354 - val_y1_output_loss: 0.7389 - val_y2_output_loss: 2.3243 - val_y1_output_root_mean_squared_error: 0.8579 - val_y2_output_root_mean_squared_error: 1.5164
# Epoch 97/500
# 614/614 [==============================] - 0s 131us/sample - loss: 5.9472 - y1_output_loss: 1.7101 - y2_output_loss: 4.1840 - y1_output_root_mean_squared_error: 1.3133 - y2_output_root_mean_squared_error: 2.0549 - val_loss: 2.4218 - val_y1_output_loss: 0.6039 - val_y2_output_loss: 1.8201 - val_y1_output_root_mean_squared_error: 0.7677 - val_y2_output_root_mean_squared_error: 1.3537
# Epoch 98/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.7776 - y1_output_loss: 0.5839 - y2_output_loss: 2.1761 - y1_output_root_mean_squared_error: 0.7647 - y2_output_root_mean_squared_error: 1.4808 - val_loss: 2.9164 - val_y1_output_loss: 0.6485 - val_y2_output_loss: 2.2431 - val_y1_output_root_mean_squared_error: 0.8118 - val_y2_output_root_mean_squared_error: 1.5024
# Epoch 99/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.7598 - y1_output_loss: 1.0528 - y2_output_loss: 2.6834 - y1_output_root_mean_squared_error: 1.0297 - y2_output_root_mean_squared_error: 1.6430 - val_loss: 2.4077 - val_y1_output_loss: 0.4695 - val_y2_output_loss: 2.0053 - val_y1_output_root_mean_squared_error: 0.6880 - val_y2_output_root_mean_squared_error: 1.3908
# Epoch 100/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.9118 - y1_output_loss: 0.6202 - y2_output_loss: 2.2885 - y1_output_root_mean_squared_error: 0.7861 - y2_output_root_mean_squared_error: 1.5146 - val_loss: 4.8659 - val_y1_output_loss: 1.3247 - val_y2_output_loss: 3.4573 - val_y1_output_root_mean_squared_error: 1.1560 - val_y2_output_root_mean_squared_error: 1.8787
# Epoch 101/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.3612 - y1_output_loss: 0.5577 - y2_output_loss: 1.8037 - y1_output_root_mean_squared_error: 0.7481 - y2_output_root_mean_squared_error: 1.3422 - val_loss: 4.1792 - val_y1_output_loss: 1.3905 - val_y2_output_loss: 2.7551 - val_y1_output_root_mean_squared_error: 1.1967 - val_y2_output_root_mean_squared_error: 1.6574
# Epoch 102/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.1563 - y1_output_loss: 0.4481 - y2_output_loss: 1.7020 - y1_output_root_mean_squared_error: 0.6674 - y2_output_root_mean_squared_error: 1.3080 - val_loss: 3.9875 - val_y1_output_loss: 1.3717 - val_y2_output_loss: 2.5730 - val_y1_output_root_mean_squared_error: 1.1749 - val_y2_output_root_mean_squared_error: 1.6147
# Epoch 103/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.0429 - y1_output_loss: 1.1502 - y2_output_loss: 2.8549 - y1_output_root_mean_squared_error: 1.0773 - y2_output_root_mean_squared_error: 1.6977 - val_loss: 2.1281 - val_y1_output_loss: 0.4299 - val_y2_output_loss: 1.7691 - val_y1_output_root_mean_squared_error: 0.6603 - val_y2_output_root_mean_squared_error: 1.3008
# Epoch 104/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.5272 - y1_output_loss: 0.8351 - y2_output_loss: 2.6605 - y1_output_root_mean_squared_error: 0.9175 - y2_output_root_mean_squared_error: 1.6387 - val_loss: 3.3560 - val_y1_output_loss: 0.9997 - val_y2_output_loss: 2.3621 - val_y1_output_root_mean_squared_error: 1.0153 - val_y2_output_root_mean_squared_error: 1.5248
# Epoch 105/500
# 614/614 [==============================] - 0s 129us/sample - loss: 2.5559 - y1_output_loss: 0.5759 - y2_output_loss: 1.9919 - y1_output_root_mean_squared_error: 0.7624 - y2_output_root_mean_squared_error: 1.4052 - val_loss: 2.8960 - val_y1_output_loss: 0.6061 - val_y2_output_loss: 2.2462 - val_y1_output_root_mean_squared_error: 0.7706 - val_y2_output_root_mean_squared_error: 1.5173
# Epoch 106/500
# 614/614 [==============================] - 0s 132us/sample - loss: 2.0349 - y1_output_loss: 0.4533 - y2_output_loss: 1.5817 - y1_output_root_mean_squared_error: 0.6750 - y2_output_root_mean_squared_error: 1.2567 - val_loss: 2.2964 - val_y1_output_loss: 0.5685 - val_y2_output_loss: 1.7338 - val_y1_output_root_mean_squared_error: 0.7512 - val_y2_output_root_mean_squared_error: 1.3161
# Epoch 107/500
# 614/614 [==============================] - 0s 129us/sample - loss: 1.8823 - y1_output_loss: 0.4076 - y2_output_loss: 1.4700 - y1_output_root_mean_squared_error: 0.6366 - y2_output_root_mean_squared_error: 1.2154 - val_loss: 3.3008 - val_y1_output_loss: 1.0031 - val_y2_output_loss: 2.3441 - val_y1_output_root_mean_squared_error: 1.0044 - val_y2_output_root_mean_squared_error: 1.5140
# Epoch 108/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.1619 - y1_output_loss: 0.4674 - y2_output_loss: 1.6903 - y1_output_root_mean_squared_error: 0.6869 - y2_output_root_mean_squared_error: 1.3000 - val_loss: 4.0013 - val_y1_output_loss: 0.9489 - val_y2_output_loss: 2.9724 - val_y1_output_root_mean_squared_error: 0.9688 - val_y2_output_root_mean_squared_error: 1.7500
# Epoch 109/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.1399 - y1_output_loss: 0.8843 - y2_output_loss: 2.2877 - y1_output_root_mean_squared_error: 0.9446 - y2_output_root_mean_squared_error: 1.4992 - val_loss: 6.6302 - val_y1_output_loss: 0.7501 - val_y2_output_loss: 5.6980 - val_y1_output_root_mean_squared_error: 0.8667 - val_y2_output_root_mean_squared_error: 2.4247
# Epoch 110/500
# 614/614 [==============================] - 0s 134us/sample - loss: 2.3962 - y1_output_loss: 0.4286 - y2_output_loss: 1.9775 - y1_output_root_mean_squared_error: 0.6545 - y2_output_root_mean_squared_error: 1.4028 - val_loss: 8.3864 - val_y1_output_loss: 1.2423 - val_y2_output_loss: 6.8729 - val_y1_output_root_mean_squared_error: 1.1239 - val_y2_output_root_mean_squared_error: 2.6690
# Epoch 111/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.1742 - y1_output_loss: 0.4992 - y2_output_loss: 1.6717 - y1_output_root_mean_squared_error: 0.7083 - y2_output_root_mean_squared_error: 1.2933 - val_loss: 3.4904 - val_y1_output_loss: 0.5282 - val_y2_output_loss: 2.8808 - val_y1_output_root_mean_squared_error: 0.7272 - val_y2_output_root_mean_squared_error: 1.7209
# Epoch 112/500
# 614/614 [==============================] - 0s 122us/sample - loss: 3.1224 - y1_output_loss: 0.8139 - y2_output_loss: 2.2831 - y1_output_root_mean_squared_error: 0.9060 - y2_output_root_mean_squared_error: 1.5171 - val_loss: 2.2169 - val_y1_output_loss: 0.4872 - val_y2_output_loss: 1.7345 - val_y1_output_root_mean_squared_error: 0.6963 - val_y2_output_root_mean_squared_error: 1.3161
# Epoch 113/500
# 614/614 [==============================] - 0s 123us/sample - loss: 1.7410 - y1_output_loss: 0.3936 - y2_output_loss: 1.3392 - y1_output_root_mean_squared_error: 0.6267 - y2_output_root_mean_squared_error: 1.1611 - val_loss: 2.5520 - val_y1_output_loss: 0.6485 - val_y2_output_loss: 1.9222 - val_y1_output_root_mean_squared_error: 0.8004 - val_y2_output_root_mean_squared_error: 1.3825
# Epoch 114/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.3704 - y1_output_loss: 0.4798 - y2_output_loss: 1.8807 - y1_output_root_mean_squared_error: 0.6939 - y2_output_root_mean_squared_error: 1.3744 - val_loss: 2.7860 - val_y1_output_loss: 0.6387 - val_y2_output_loss: 2.1062 - val_y1_output_root_mean_squared_error: 0.8009 - val_y2_output_root_mean_squared_error: 1.4644
# Epoch 115/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.6656 - y1_output_loss: 0.6718 - y2_output_loss: 1.9689 - y1_output_root_mean_squared_error: 0.8235 - y2_output_root_mean_squared_error: 1.4098 - val_loss: 2.0119 - val_y1_output_loss: 0.4758 - val_y2_output_loss: 1.5478 - val_y1_output_root_mean_squared_error: 0.6929 - val_y2_output_root_mean_squared_error: 1.2376
# Epoch 116/500
# 614/614 [==============================] - 0s 124us/sample - loss: 1.7794 - y1_output_loss: 0.4853 - y2_output_loss: 1.2797 - y1_output_root_mean_squared_error: 0.6983 - y2_output_root_mean_squared_error: 1.1366 - val_loss: 1.9628 - val_y1_output_loss: 0.4065 - val_y2_output_loss: 1.5985 - val_y1_output_root_mean_squared_error: 0.6336 - val_y2_output_root_mean_squared_error: 1.2496
# Epoch 117/500
# 614/614 [==============================] - 0s 125us/sample - loss: 1.6466 - y1_output_loss: 0.3682 - y2_output_loss: 1.3079 - y1_output_root_mean_squared_error: 0.6006 - y2_output_root_mean_squared_error: 1.1339 - val_loss: 8.5142 - val_y1_output_loss: 1.8338 - val_y2_output_loss: 6.5955 - val_y1_output_root_mean_squared_error: 1.3789 - val_y2_output_root_mean_squared_error: 2.5716
# Epoch 118/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.1688 - y1_output_loss: 0.5419 - y2_output_loss: 1.6079 - y1_output_root_mean_squared_error: 0.7389 - y2_output_root_mean_squared_error: 1.2739 - val_loss: 2.1402 - val_y1_output_loss: 0.4084 - val_y2_output_loss: 1.7867 - val_y1_output_root_mean_squared_error: 0.6347 - val_y2_output_root_mean_squared_error: 1.3181
# Epoch 119/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.0982 - y1_output_loss: 0.6939 - y2_output_loss: 2.3789 - y1_output_root_mean_squared_error: 0.8356 - y2_output_root_mean_squared_error: 1.5492 - val_loss: 2.6500 - val_y1_output_loss: 0.4888 - val_y2_output_loss: 2.2061 - val_y1_output_root_mean_squared_error: 0.7046 - val_y2_output_root_mean_squared_error: 1.4675
# Epoch 120/500
# 614/614 [==============================] - 0s 127us/sample - loss: 1.5653 - y1_output_loss: 0.3996 - y2_output_loss: 1.1685 - y1_output_root_mean_squared_error: 0.6276 - y2_output_root_mean_squared_error: 1.0823 - val_loss: 2.4528 - val_y1_output_loss: 0.6327 - val_y2_output_loss: 1.8492 - val_y1_output_root_mean_squared_error: 0.8084 - val_y2_output_root_mean_squared_error: 1.3414
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.2922 - y1_output_loss: 0.0981 - y2_output_loss: 0.1930 - y1_output_root_mean_squared_error: 0.3140 - y2_output_root_mean_squared_error: 0.4400 - val_loss: 1.9350 - val_y1_output_loss: 0.3817 - val_y2_output_loss: 1.5304 - val_y1_output_root_mean_squared_error: 0.6276 - val_y2_output_root_mean_squared_error: 1.2414
# Epoch 462/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4587 - y1_output_loss: 0.1357 - y2_output_loss: 0.3234 - y1_output_root_mean_squared_error: 0.3700 - y2_output_root_mean_squared_error: 0.5673 - val_loss: 1.3440 - val_y1_output_loss: 0.3643 - val_y2_output_loss: 0.9487 - val_y1_output_root_mean_squared_error: 0.6106 - val_y2_output_root_mean_squared_error: 0.9854
# Epoch 463/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3349 - y1_output_loss: 0.1082 - y2_output_loss: 0.2245 - y1_output_root_mean_squared_error: 0.3298 - y2_output_root_mean_squared_error: 0.4755 - val_loss: 0.9084 - val_y1_output_loss: 0.2752 - val_y2_output_loss: 0.6231 - val_y1_output_root_mean_squared_error: 0.5314 - val_y2_output_root_mean_squared_error: 0.7912
# Epoch 464/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3940 - y1_output_loss: 0.1126 - y2_output_loss: 0.2797 - y1_output_root_mean_squared_error: 0.3350 - y2_output_root_mean_squared_error: 0.5308 - val_loss: 0.8079 - val_y1_output_loss: 0.2861 - val_y2_output_loss: 0.5025 - val_y1_output_root_mean_squared_error: 0.5444 - val_y2_output_root_mean_squared_error: 0.7152
# Epoch 465/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3812 - y1_output_loss: 0.1227 - y2_output_loss: 0.2606 - y1_output_root_mean_squared_error: 0.3452 - y2_output_root_mean_squared_error: 0.5119 - val_loss: 0.8909 - val_y1_output_loss: 0.3523 - val_y2_output_loss: 0.5184 - val_y1_output_root_mean_squared_error: 0.6042 - val_y2_output_root_mean_squared_error: 0.7252
# Epoch 466/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4032 - y1_output_loss: 0.1189 - y2_output_loss: 0.2889 - y1_output_root_mean_squared_error: 0.3450 - y2_output_root_mean_squared_error: 0.5331 - val_loss: 1.4096 - val_y1_output_loss: 0.3822 - val_y2_output_loss: 1.0071 - val_y1_output_root_mean_squared_error: 0.6296 - val_y2_output_root_mean_squared_error: 1.0066
# Epoch 467/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3050 - y1_output_loss: 0.1015 - y2_output_loss: 0.2034 - y1_output_root_mean_squared_error: 0.3179 - y2_output_root_mean_squared_error: 0.4515 - val_loss: 1.4488 - val_y1_output_loss: 0.3660 - val_y2_output_loss: 1.0509 - val_y1_output_root_mean_squared_error: 0.6111 - val_y2_output_root_mean_squared_error: 1.0370
# Epoch 468/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3309 - y1_output_loss: 0.1034 - y2_output_loss: 0.2268 - y1_output_root_mean_squared_error: 0.3223 - y2_output_root_mean_squared_error: 0.4765 - val_loss: 0.8707 - val_y1_output_loss: 0.2635 - val_y2_output_loss: 0.5912 - val_y1_output_root_mean_squared_error: 0.5194 - val_y2_output_root_mean_squared_error: 0.7752
# Epoch 469/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3382 - y1_output_loss: 0.0976 - y2_output_loss: 0.2380 - y1_output_root_mean_squared_error: 0.3138 - y2_output_root_mean_squared_error: 0.4896 - val_loss: 0.8383 - val_y1_output_loss: 0.2743 - val_y2_output_loss: 0.5470 - val_y1_output_root_mean_squared_error: 0.5330 - val_y2_output_root_mean_squared_error: 0.7444
# Epoch 470/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3991 - y1_output_loss: 0.1122 - y2_output_loss: 0.2855 - y1_output_root_mean_squared_error: 0.3348 - y2_output_root_mean_squared_error: 0.5357 - val_loss: 1.4276 - val_y1_output_loss: 0.4713 - val_y2_output_loss: 0.9191 - val_y1_output_root_mean_squared_error: 0.6963 - val_y2_output_root_mean_squared_error: 0.9710
# Epoch 471/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3976 - y1_output_loss: 0.1169 - y2_output_loss: 0.2793 - y1_output_root_mean_squared_error: 0.3416 - y2_output_root_mean_squared_error: 0.5300 - val_loss: 1.0364 - val_y1_output_loss: 0.3363 - val_y2_output_loss: 0.6839 - val_y1_output_root_mean_squared_error: 0.5906 - val_y2_output_root_mean_squared_error: 0.8292
# Epoch 472/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4263 - y1_output_loss: 0.1264 - y2_output_loss: 0.2972 - y1_output_root_mean_squared_error: 0.3566 - y2_output_root_mean_squared_error: 0.5469 - val_loss: 1.2140 - val_y1_output_loss: 0.3275 - val_y2_output_loss: 0.8573 - val_y1_output_root_mean_squared_error: 0.5802 - val_y2_output_root_mean_squared_error: 0.9367
# Epoch 473/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3119 - y1_output_loss: 0.0958 - y2_output_loss: 0.2174 - y1_output_root_mean_squared_error: 0.3100 - y2_output_root_mean_squared_error: 0.4645 - val_loss: 1.0863 - val_y1_output_loss: 0.2520 - val_y2_output_loss: 0.8219 - val_y1_output_root_mean_squared_error: 0.5107 - val_y2_output_root_mean_squared_error: 0.9086
# Epoch 474/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3426 - y1_output_loss: 0.1174 - y2_output_loss: 0.2304 - y1_output_root_mean_squared_error: 0.3409 - y2_output_root_mean_squared_error: 0.4758 - val_loss: 1.7956 - val_y1_output_loss: 0.6154 - val_y2_output_loss: 1.1246 - val_y1_output_root_mean_squared_error: 0.7972 - val_y2_output_root_mean_squared_error: 1.0771
# Epoch 475/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4287 - y1_output_loss: 0.1275 - y2_output_loss: 0.3024 - y1_output_root_mean_squared_error: 0.3571 - y2_output_root_mean_squared_error: 0.5488 - val_loss: 1.2329 - val_y1_output_loss: 0.3183 - val_y2_output_loss: 0.8938 - val_y1_output_root_mean_squared_error: 0.5727 - val_y2_output_root_mean_squared_error: 0.9513
# Epoch 476/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3507 - y1_output_loss: 0.1165 - y2_output_loss: 0.2324 - y1_output_root_mean_squared_error: 0.3418 - y2_output_root_mean_squared_error: 0.4836 - val_loss: 0.7803 - val_y1_output_loss: 0.2570 - val_y2_output_loss: 0.5088 - val_y1_output_root_mean_squared_error: 0.5152 - val_y2_output_root_mean_squared_error: 0.7175
# Epoch 477/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.2750 - y1_output_loss: 0.0950 - y2_output_loss: 0.1807 - y1_output_root_mean_squared_error: 0.3091 - y2_output_root_mean_squared_error: 0.4236 - val_loss: 1.3352 - val_y1_output_loss: 0.3433 - val_y2_output_loss: 0.9596 - val_y1_output_root_mean_squared_error: 0.5945 - val_y2_output_root_mean_squared_error: 0.9908
# Epoch 478/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4071 - y1_output_loss: 0.1333 - y2_output_loss: 0.2730 - y1_output_root_mean_squared_error: 0.3653 - y2_output_root_mean_squared_error: 0.5231 - val_loss: 0.9651 - val_y1_output_loss: 0.2740 - val_y2_output_loss: 0.6771 - val_y1_output_root_mean_squared_error: 0.5301 - val_y2_output_root_mean_squared_error: 0.8271
# Epoch 479/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.7807 - y1_output_loss: 0.1754 - y2_output_loss: 0.6061 - y1_output_root_mean_squared_error: 0.4177 - y2_output_root_mean_squared_error: 0.7786 - val_loss: 1.7940 - val_y1_output_loss: 0.4110 - val_y2_output_loss: 1.3357 - val_y1_output_root_mean_squared_error: 0.6511 - val_y2_output_root_mean_squared_error: 1.1705
# Epoch 480/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4117 - y1_output_loss: 0.1341 - y2_output_loss: 0.2845 - y1_output_root_mean_squared_error: 0.3608 - y2_output_root_mean_squared_error: 0.5306 - val_loss: 1.1723 - val_y1_output_loss: 0.6282 - val_y2_output_loss: 0.5246 - val_y1_output_root_mean_squared_error: 0.8033 - val_y2_output_root_mean_squared_error: 0.7259
# Epoch 481/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3677 - y1_output_loss: 0.1244 - y2_output_loss: 0.2399 - y1_output_root_mean_squared_error: 0.3543 - y2_output_root_mean_squared_error: 0.4921 - val_loss: 0.8036 - val_y1_output_loss: 0.2849 - val_y2_output_loss: 0.5033 - val_y1_output_root_mean_squared_error: 0.5423 - val_y2_output_root_mean_squared_error: 0.7137
# Epoch 482/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.4365 - y1_output_loss: 0.1138 - y2_output_loss: 0.3322 - y1_output_root_mean_squared_error: 0.3384 - y2_output_root_mean_squared_error: 0.5674 - val_loss: 2.2781 - val_y1_output_loss: 0.3621 - val_y2_output_loss: 1.8436 - val_y1_output_root_mean_squared_error: 0.6126 - val_y2_output_root_mean_squared_error: 1.3794
# Epoch 483/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3515 - y1_output_loss: 0.0997 - y2_output_loss: 0.2503 - y1_output_root_mean_squared_error: 0.3169 - y2_output_root_mean_squared_error: 0.5011 - val_loss: 1.2040 - val_y1_output_loss: 0.4167 - val_y2_output_loss: 0.7802 - val_y1_output_root_mean_squared_error: 0.6507 - val_y2_output_root_mean_squared_error: 0.8835
# Epoch 484/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3151 - y1_output_loss: 0.1124 - y2_output_loss: 0.2041 - y1_output_root_mean_squared_error: 0.3360 - y2_output_root_mean_squared_error: 0.4496 - val_loss: 1.2669 - val_y1_output_loss: 0.3143 - val_y2_output_loss: 0.9402 - val_y1_output_root_mean_squared_error: 0.5656 - val_y2_output_root_mean_squared_error: 0.9732
# Epoch 485/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3313 - y1_output_loss: 0.1158 - y2_output_loss: 0.2133 - y1_output_root_mean_squared_error: 0.3409 - y2_output_root_mean_squared_error: 0.4637 - val_loss: 0.9200 - val_y1_output_loss: 0.2801 - val_y2_output_loss: 0.6272 - val_y1_output_root_mean_squared_error: 0.5372 - val_y2_output_root_mean_squared_error: 0.7947
# Epoch 486/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3383 - y1_output_loss: 0.1104 - y2_output_loss: 0.2305 - y1_output_root_mean_squared_error: 0.3325 - y2_output_root_mean_squared_error: 0.4773 - val_loss: 1.6268 - val_y1_output_loss: 0.3981 - val_y2_output_loss: 1.1926 - val_y1_output_root_mean_squared_error: 0.6413 - val_y2_output_root_mean_squared_error: 1.1025
# Epoch 487/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.5240 - y1_output_loss: 0.1304 - y2_output_loss: 0.3901 - y1_output_root_mean_squared_error: 0.3612 - y2_output_root_mean_squared_error: 0.6273 - val_loss: 0.8389 - val_y1_output_loss: 0.3014 - val_y2_output_loss: 0.5186 - val_y1_output_root_mean_squared_error: 0.5568 - val_y2_output_root_mean_squared_error: 0.7272
# Epoch 488/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.3233 - y1_output_loss: 0.0985 - y2_output_loss: 0.2224 - y1_output_root_mean_squared_error: 0.3151 - y2_output_root_mean_squared_error: 0.4733 - val_loss: 0.9021 - val_y1_output_loss: 0.2870 - val_y2_output_loss: 0.5971 - val_y1_output_root_mean_squared_error: 0.5416 - val_y2_output_root_mean_squared_error: 0.7802
# Epoch 489/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3467 - y1_output_loss: 0.1122 - y2_output_loss: 0.2335 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.4846 - val_loss: 0.9172 - val_y1_output_loss: 0.3053 - val_y2_output_loss: 0.6022 - val_y1_output_root_mean_squared_error: 0.5610 - val_y2_output_root_mean_squared_error: 0.7762
# Epoch 490/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.5681 - y1_output_loss: 0.1356 - y2_output_loss: 0.4335 - y1_output_root_mean_squared_error: 0.3662 - y2_output_root_mean_squared_error: 0.6588 - val_loss: 1.2544 - val_y1_output_loss: 0.3327 - val_y2_output_loss: 0.8930 - val_y1_output_root_mean_squared_error: 0.5863 - val_y2_output_root_mean_squared_error: 0.9543
# Epoch 491/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3196 - y1_output_loss: 0.1076 - y2_output_loss: 0.2198 - y1_output_root_mean_squared_error: 0.3243 - y2_output_root_mean_squared_error: 0.4630 - val_loss: 2.3502 - val_y1_output_loss: 0.4174 - val_y2_output_loss: 1.9058 - val_y1_output_root_mean_squared_error: 0.6556 - val_y2_output_root_mean_squared_error: 1.3858
# Epoch 492/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.4186 - y1_output_loss: 0.1156 - y2_output_loss: 0.3044 - y1_output_root_mean_squared_error: 0.3403 - y2_output_root_mean_squared_error: 0.5502 - val_loss: 0.7630 - val_y1_output_loss: 0.2720 - val_y2_output_loss: 0.4769 - val_y1_output_root_mean_squared_error: 0.5283 - val_y2_output_root_mean_squared_error: 0.6957
# Epoch 493/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.5195 - y1_output_loss: 0.1488 - y2_output_loss: 0.3805 - y1_output_root_mean_squared_error: 0.3806 - y2_output_root_mean_squared_error: 0.6121 - val_loss: 1.1073 - val_y1_output_loss: 0.3339 - val_y2_output_loss: 0.7600 - val_y1_output_root_mean_squared_error: 0.5873 - val_y2_output_root_mean_squared_error: 0.8731
# Epoch 494/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3850 - y1_output_loss: 0.1206 - y2_output_loss: 0.2726 - y1_output_root_mean_squared_error: 0.3479 - y2_output_root_mean_squared_error: 0.5138 - val_loss: 2.1534 - val_y1_output_loss: 0.3350 - val_y2_output_loss: 1.7469 - val_y1_output_root_mean_squared_error: 0.5885 - val_y2_output_root_mean_squared_error: 1.3443
# Epoch 495/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3540 - y1_output_loss: 0.1114 - y2_output_loss: 0.2422 - y1_output_root_mean_squared_error: 0.3344 - y2_output_root_mean_squared_error: 0.4921 - val_loss: 1.2260 - val_y1_output_loss: 0.4090 - val_y2_output_loss: 0.7836 - val_y1_output_root_mean_squared_error: 0.6487 - val_y2_output_root_mean_squared_error: 0.8973
# Epoch 496/500
# 614/614 [==============================] - 0s 124us/sample - loss: 0.3530 - y1_output_loss: 0.1126 - y2_output_loss: 0.2385 - y1_output_root_mean_squared_error: 0.3359 - y2_output_root_mean_squared_error: 0.4901 - val_loss: 0.8506 - val_y1_output_loss: 0.3207 - val_y2_output_loss: 0.5131 - val_y1_output_root_mean_squared_error: 0.5744 - val_y2_output_root_mean_squared_error: 0.7216
# Epoch 497/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3613 - y1_output_loss: 0.1226 - y2_output_loss: 0.2366 - y1_output_root_mean_squared_error: 0.3500 - y2_output_root_mean_squared_error: 0.4887 - val_loss: 0.8209 - val_y1_output_loss: 0.2922 - val_y2_output_loss: 0.5140 - val_y1_output_root_mean_squared_error: 0.5497 - val_y2_output_root_mean_squared_error: 0.7202
# Epoch 498/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.2867 - y1_output_loss: 0.1004 - y2_output_loss: 0.1881 - y1_output_root_mean_squared_error: 0.3153 - y2_output_root_mean_squared_error: 0.4328 - val_loss: 1.8714 - val_y1_output_loss: 0.6038 - val_y2_output_loss: 1.2139 - val_y1_output_root_mean_squared_error: 0.7893 - val_y2_output_root_mean_squared_error: 1.1173
# Epoch 499/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3662 - y1_output_loss: 0.1086 - y2_output_loss: 0.2580 - y1_output_root_mean_squared_error: 0.3308 - y2_output_root_mean_squared_error: 0.5068 - val_loss: 0.6915 - val_y1_output_loss: 0.2459 - val_y2_output_loss: 0.4390 - val_y1_output_root_mean_squared_error: 0.5034 - val_y2_output_root_mean_squared_error: 0.6619
# Epoch 500/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.6503 - y1_output_loss: 0.1467 - y2_output_loss: 0.4993 - y1_output_root_mean_squared_error: 0.3827 - y2_output_root_mean_squared_error: 0.7098 - val_loss: 0.9424 - val_y1_output_loss: 0.3952 - val_y2_output_loss: 0.5275 - val_y1_output_root_mean_squared_error: 0.6377 - val_y2_output_root_mean_squared_error: 0.7319

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 36us/sample - loss: 0.9424 - y1_output_loss: 0.4030 - y2_output_loss: 0.5334 - y1_output_root_mean_squared_error: 0.6377 - y2_output_root_mean_squared_error: 0.7319
# Loss = 0.9423702738501809, Y1_loss = 0.40303176641464233, Y1_mse = 0.637680172920227, Y2_loss = 0.5334492325782776, Y2_mse = 0.7319387197494507

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
